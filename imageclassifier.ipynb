# %% [markdown]
# # Install Dependencies and Setup

# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\user1\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: opencv-python in c:\users\user1\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: matplotlib in c:\users\user1\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: setuptools in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: packaging in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy>=1.20 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user1\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user1\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user1\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user1\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\user1\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user1\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user1\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user1\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\user1\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user1\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user1\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user1\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)

# %%
import tensorflow as tf
import os

# %% [markdown]
# # Remove dodgy images

# %%
import cv2
import imghdr

# %%
data_dir = 'data'

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            os.remove(image_path)

# %% [markdown]
# # 3. Load Data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 305 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # Scaling

# %%
data = data.map(lambda x,y: (x/255, y))

# %% [markdown]
# # Spliting

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # Model Building

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 7/7 [==============================] - 14s 2s/step - loss: 1.2327 - accuracy: 0.5223 - val_loss: 0.7015 - val_accuracy: 0.4531
# Epoch 2/20
# 7/7 [==============================] - 14s 2s/step - loss: 0.6908 - accuracy: 0.4866 - val_loss: 0.6365 - val_accuracy: 0.4688
# Epoch 3/20
# 7/7 [==============================] - 14s 2s/step - loss: 0.6427 - accuracy: 0.5580 - val_loss: 0.6386 - val_accuracy: 0.8281
# Epoch 4/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.5913 - accuracy: 0.7232 - val_loss: 0.5467 - val_accuracy: 0.8750
# Epoch 5/20
# 7/7 [==============================] - 14s 2s/step - loss: 0.5499 - accuracy: 0.7812 - val_loss: 0.5403 - val_accuracy: 0.7188
# Epoch 6/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.6611 - accuracy: 0.6562 - val_loss: 0.6409 - val_accuracy: 0.6094
# Epoch 7/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.5142 - accuracy: 0.7946 - val_loss: 0.4732 - val_accuracy: 0.7812
# Epoch 8/20
# 7/7 [==============================] - 14s 2s/step - loss: 0.4236 - accuracy: 0.8527 - val_loss: 0.3630 - val_accuracy: 0.8906
# Epoch 9/20
# 7/7 [==============================] - 14s 2s/step - loss: 0.3885 - accuracy: 0.8348 - val_loss: 0.2856 - val_accuracy: 0.8906
# Epoch 10/20
# 7/7 [==============================] - 14s 2s/step - loss: 0.3129 - accuracy: 0.8884 - val_loss: 0.3268 - val_accuracy: 0.9062
# Epoch 11/20
# 7/7 [==============================] - 14s 2s/step - loss: 0.3078 - accuracy: 0.9018 - val_loss: 0.2213 - val_accuracy: 0.8750
# Epoch 12/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.2284 - accuracy: 0.9241 - val_loss: 0.1127 - val_accuracy: 1.0000
# Epoch 13/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.1767 - accuracy: 0.9330 - val_loss: 0.1023 - val_accuracy: 0.9844
# Epoch 14/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.1270 - accuracy: 0.9821 - val_loss: 0.1550 - val_accuracy: 0.9531
# Epoch 15/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.0884 - accuracy: 0.9866 - val_loss: 0.0466 - val_accuracy: 1.0000
# Epoch 16/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.0818 - accuracy: 0.9732 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 17/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.0757 - accuracy: 0.9777 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 18/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.0486 - accuracy: 0.9911 - val_loss: 0.0643 - val_accuracy: 0.9688
# Epoch 19/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.0285 - accuracy: 0.9911 - val_loss: 0.0804 - val_accuracy: 0.9688
# Epoch 20/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.0541 - accuracy: 0.9866 - val_loss: 0.0269 - val_accuracy: 1.0000

# %% [markdown]
# # Performance Visualization

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Metrics

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
precision = Precision()
recall = Recall()
accuracy = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    prediction = model.predict(X)
    precision.update_state(y, prediction)
    recall.update_state(y, prediction)
    accuracy.update_state(y, prediction)
# Out:
# 1/1 [==============================] - 0s 154ms/step

# %%
print(f'Recall:{recall.result().numpy()}, Precision:{precision.result().numpy()}, Accuracy:{accuracy.result().numpy()}')
# Out:
# Recall:1.0, Precision:1.0, Accuracy:1.0

# %% [markdown]
# # Test

# %%
import cv2

# %%
img = cv2.imread('happytest.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 48ms/step

# %%
if yhat > 0.5: 
    print(f'Predicted class is Sad')
else:
    print(f'Predicted class is Happy')
# Out:
# Predicted class is Happy

# %% [markdown]
# # Model Saving

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','markI.h5'))
